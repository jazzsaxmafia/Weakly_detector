# %%
# %matplotlib inline
# %run test.caltech.py
# Out:
# toaster
# toaster
# toaster
# toaster
# toaster
# toaster
# toaster
# toaster
# toaster
# toaster
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
# tuning-fork
